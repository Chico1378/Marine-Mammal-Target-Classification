# %%
import random
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# **设置随机种子**
SEED = 300   #300的时候效果不错
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# **1️⃣ 加载数据**
X_train = np.load(r"D:\Dataset\Temp_Results\MFCC\X_train_mfcc_cnn.npy")
Y_train = np.load(r"D:\Dataset\Temp_Results\Train_Test\y_train.npy")
X_test = np.load(r"D:\Dataset\Temp_Results\MFCC\X_test_mfcc_cnn.npy")
Y_test = np.load(r"D:\Dataset\Temp_Results\Train_Test\y_test.npy")

# **2️⃣ 数据预处理**
X_train = X_train.astype(np.float32) / 255.0
X_test = X_test.astype(np.float32) / 255.0

X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

num_classes = len(np.unique(Y_train))
Y_train = to_categorical(Y_train, num_classes)
Y_test = to_categorical(Y_test, num_classes)

# **3️⃣ 构建 CNN 模型**
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.0005), input_shape=(128, 128, 1)),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.0005)),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.0005)),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.0005)),
    Dropout(0.4),
    
    Dense(num_classes, activation='softmax')
])

# **4️⃣ 编译模型**
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# **5️⃣ 训练模型，使用 EarlyStopping 和 ReduceLROnPlateau**
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

history = model.fit(X_train, Y_train, epochs=30, batch_size=32,
                    validation_data=(X_test, Y_test),
                    callbacks=[reduce_lr])  #去掉了early stop

# **6️⃣ 评估模型**
test_loss, test_acc = model.evaluate(X_test, Y_test, verbose=2)
print(f"\n✅ 测试集准确率: {test_acc:.4f}")

# **7️⃣ 计算分类报告和混淆矩阵**
Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_test, axis=1)

accuracy = accuracy_score(Y_true, Y_pred_classes)
print(f"🎯 测试准确率: {accuracy:.4f}")

print("\n📊 分类报告:")
print(classification_report(Y_true, Y_pred_classes))

conf_matrix = confusion_matrix(Y_true, Y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(Y_true), yticklabels=np.unique(Y_true))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# **8️⃣ 保存模型**
model.save("cnn_MFCC_model.keras")
print("✅ 模型已保存为 cnn_MFCC_model.keras")
# Out:
# Epoch 1/30
# d:\Venv\envs\TarRec\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.3216 - loss: 2.1654 - val_accuracy: 0.5385 - val_loss: 1.2935 - learning_rate: 0.0010
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.3849 - loss: 1.2833 - val_accuracy: 0.4872 - val_loss: 1.2739 - learning_rate: 0.0010
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.5004 - loss: 1.1812 - val_accuracy: 0.6581 - val_loss: 1.1434 - learning_rate: 0.0010
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7165 - loss: 0.8855 - val_accuracy: 0.7436 - val_loss: 1.0706 - learning_rate: 0.0010
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.7792 - loss: 0.7141 - val_accuracy: 0.7436 - val_loss: 1.1238 - learning_rate: 0.0010
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.8398 - loss: 0.6122 - val_accuracy: 0.7436 - val_loss: 1.2376 - learning_rate: 0.0010
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8624 - loss: 0.5067 - val_accuracy: 0.7949 - val_loss: 1.0656 - learning_rate: 0.0010
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.9140 - loss: 0.4061 - val_accuracy: 0.8034 - val_loss: 1.0610 - learning_rate: 0.0010
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.9280 - loss: 0.3586 - val_accuracy: 0.8291 - val_loss: 0.9737 - learning_rate: 0.0010
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.9205 - loss: 0.3348 - val_accuracy: 0.8632 - val_loss: 0.8400 - learning_rate: 0.0010
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.9332 - loss: 0.3078 - val_accuracy: 0.8034 - val_loss: 1.0947 - learning_rate: 0.0010
# Epoch 12/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.9463 - loss: 0.2799 - val_accuracy: 0.8120 - val_loss: 1.0505 - learning_rate: 0.0010
# Epoch 13/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.9598 - loss: 0.2526 - val_accuracy: 0.7949 - val_loss: 1.0135 - learning_rate: 0.0010
# Epoch 14/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9610 - loss: 0.2472 - val_accuracy: 0.8034 - val_loss: 0.9818 - learning_rate: 0.0010
# Epoch 15/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - accuracy: 0.9755 - loss: 0.2092 - val_accuracy: 0.8376 - val_loss: 1.1574 - learning_rate: 0.0010
# Epoch 16/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9881 - loss: 0.1969 - val_accuracy: 0.8376 - val_loss: 1.1218 - learning_rate: 5.0000e-04
# Epoch 17/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 0.9653 - loss: 0.2347 - val_accuracy: 0.7607 - val_loss: 1.0396 - learning_rate: 5.0000e-04
# Epoch 18/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - accuracy: 0.9482 - loss: 0.2779 - val_accuracy: 0.8547 - val_loss: 0.9076 - learning_rate: 5.0000e-04
# Epoch 19/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9855 - loss: 0.2053 - val_accuracy: 0.8205 - val_loss: 0.9969 - learning_rate: 5.0000e-04
# Epoch 20/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.9842 - loss: 0.1783 - val_accuracy: 0.8034 - val_loss: 1.2561 - learning_rate: 5.0000e-04
# Epoch 21/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9857 - loss: 0.1746 - val_accuracy: 0.8462 - val_loss: 1.0954 - learning_rate: 2.5000e-04
# Epoch 22/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.9887 - loss: 0.1644 - val_accuracy: 0.8291 - val_loss: 1.1070 - learning_rate: 2.5000e-04
# Epoch 23/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9959 - loss: 0.1523 - val_accuracy: 0.8291 - val_loss: 1.1062 - learning_rate: 2.5000e-04
# Epoch 24/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9921 - loss: 0.1681 - val_accuracy: 0.8547 - val_loss: 1.1192 - learning_rate: 2.5000e-04
# Epoch 25/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - accuracy: 0.9987 - loss: 0.1449 - val_accuracy: 0.8376 - val_loss: 1.1032 - learning_rate: 2.5000e-04
# Epoch 26/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9935 - loss: 0.1530 - val_accuracy: 0.8376 - val_loss: 1.1064 - learning_rate: 1.2500e-04
# Epoch 27/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9971 - loss: 0.1432 - val_accuracy: 0.8205 - val_loss: 1.1318 - learning_rate: 1.2500e-04
# Epoch 28/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9967 - loss: 0.1448 - val_accuracy: 0.8376 - val_loss: 1.0993 - learning_rate: 1.2500e-04
# Epoch 29/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9987 - loss: 0.1431 - val_accuracy: 0.8376 - val_loss: 1.0992 - learning_rate: 1.2500e-04
# Epoch 30/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9982 - loss: 0.1376 - val_accuracy: 0.8462 - val_loss: 1.1269 - learning_rate: 1.2500e-04
# 4/4 - 0s - 40ms/step - accuracy: 0.8462 - loss: 1.1269
#
# ✅ 测试集准确率: 0.8462
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 🎯 测试准确率: 0.8462
#
# 📊 分类报告:
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84        48
#            1       0.86      0.91      0.88        33
#            2       0.76      0.89      0.82        36
#
#     accuracy                           0.85       117
#    macro avg       0.85      0.86      0.85       117
# weighted avg       0.86      0.85      0.85       117
# ✅ 模型已保存为 cnn_MFCC_model.keras

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tensorflow.keras.models import Model

# 加载训练数据
X_train = np.load(r"D:\Dataset\Temp_Results\MFCC\X_train_mfcc_cnn.npy")
Y_train = np.load(r"D:\Dataset\Temp_Results\Train_Test\y_train.npy")

# 加载模型（确保模型已训练并保存）
from tensorflow.keras.models import load_model
model = load_model("cnn_MFCC_model.keras")

# 获取 CNN 中的特征层（选择倒数第二层的输出）
feature_model = Model(inputs=model.layers[0].input, outputs=model.layers[-2].output)

features = feature_model.predict(X_train)

# 使用 t-SNE 降维到 2D
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_embedded = tsne.fit_transform(features)

# 可视化 t-SNE 结果
plt.figure(figsize=(10, 7))
scatter = plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y_train, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, label="Class Label")
plt.title("t-SNE Visualization of CNN Features")
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
