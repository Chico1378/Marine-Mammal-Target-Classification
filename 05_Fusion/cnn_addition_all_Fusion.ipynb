# %%
import os
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, Add
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# **设置随机种子**
SEED = 300   #300的时候效果不错
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# 1️⃣ 加载训练好的 CNN 模型
model_mfcc = load_model(r"D:\Dataset\Temp_Results\Model\cnn_MFCC_model.keras")
model_wavelet = load_model(r"D:\Dataset\Temp_Results\Model\cnn_wavelet_model_abs.keras")
model_dd = load_model(r"D:\Dataset\Temp_Results\Model\cnn_DelayDoppler_model.keras")

# 2️⃣ 提取特征层
feature_extractor_mfcc = Model(inputs=model_mfcc.inputs, outputs=model_mfcc.get_layer("dense").output)
feature_extractor_wavelet = Model(inputs=model_wavelet.inputs, outputs=model_wavelet.get_layer("dense").output)
feature_extractor_dd = Model(inputs=model_dd.inputs, outputs=model_dd.get_layer("dense").output)

# 3️⃣ 加载训练数据和测试数据
X_train_mfcc = np.load(r"D:\Dataset\Temp_Results\MFCC\X_train_mfcc_cnn.npy")
X_train_wavelet = np.load(r"D:\Dataset\Temp_Results\Wavelet\X_train_cwt_abs.npy")
X_train_wavelet = np.expand_dims(X_train_wavelet, axis=-1)
X_train_dd = np.load(r"D:\Dataset\Temp_Results\DelayDoppler\X_train_dd_cnn.npy")
Y_train = np.load(r"D:\Dataset\Temp_Results\Train_Test\y_train.npy")

X_test_mfcc = np.load(r"D:\Dataset\Temp_Results\MFCC\X_test_mfcc_cnn.npy")
X_test_wavelet = np.load(r"D:\Dataset\Temp_Results\Wavelet\X_test_cwt_abs.npy")
X_test_wavelet = np.expand_dims(X_test_wavelet, axis=-1)
X_test_dd = np.load(r"D:\Dataset\Temp_Results\DelayDoppler\X_test_dd_cnn.npy")
Y_test = np.load(r"D:\Dataset\Temp_Results\Train_Test\y_test.npy")

# 归一化数据
X_train_mfcc = X_train_mfcc.astype(np.float32) / 255.0
X_train_wavelet = X_train_wavelet.astype(np.float32) / 255.0
X_train_dd = X_train_dd.astype(np.float32) / 255.0

X_test_mfcc = X_test_mfcc.astype(np.float32) / 255.0
X_test_wavelet = X_test_wavelet.astype(np.float32) / 255.0
X_test_dd = X_test_dd.astype(np.float32) / 255.0

# 4️⃣ 提取三个模型的特征
features_train_mfcc = feature_extractor_mfcc.predict(X_train_mfcc)
features_train_wavelet = feature_extractor_wavelet.predict(X_train_wavelet)
features_train_dd = feature_extractor_dd.predict(X_train_dd)

features_test_mfcc = feature_extractor_mfcc.predict(X_test_mfcc)
features_test_wavelet = feature_extractor_wavelet.predict(X_test_wavelet)
features_test_dd = feature_extractor_dd.predict(X_test_dd)

# 5️⃣ 逐元素加法融合特征（要求特征维度一致）
fused_train_features = features_train_mfcc + features_train_wavelet + features_train_dd
fused_test_features = features_test_mfcc + features_test_wavelet + features_test_dd

# 6️⃣ 处理标签
num_classes = len(np.unique(Y_train))
Y_train = to_categorical(Y_train, num_classes)
Y_test = to_categorical(Y_test, num_classes)

# 7️⃣ 构建融合模型
input_dim = fused_train_features.shape[1]
input_layer = Input(shape=(input_dim,))

x = Dense(128, activation='relu')(input_layer)
x = Dropout(0.4)(x)
x = Dense(num_classes, activation='softmax')(x)

fusion_model = Model(inputs=input_layer, outputs=x)

# 8️⃣ 编译模型
fusion_model.compile(optimizer=Adam(learning_rate=0.001),
                     loss='categorical_crossentropy',
                     metrics=['accuracy'])

# 9️⃣ 训练模型
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

history = fusion_model.fit(fused_train_features, Y_train, epochs=30, batch_size=32,
                           validation_split=0.2, callbacks=[reduce_lr, early_stopping])

# 🔟 评估融合模型
test_loss, test_acc = fusion_model.evaluate(fused_test_features, Y_test, verbose=2)
print(f"\n✅ 融合模型测试集准确率: {test_acc:.4f}")

# 计算分类报告和混淆矩阵
Y_pred = fusion_model.predict(fused_test_features)
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_test, axis=1)

print("\n📊 分类报告:")
print(classification_report(Y_true, Y_pred_classes,digits=4))

conf_matrix = confusion_matrix(Y_true, Y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(Y_true), yticklabels=np.unique(Y_true))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# 保存最终融合模型
fusion_model.save(r"D:\Dataset\Temp_Results\Model\cnn_addition_fusion_all_model.keras")
print("✅ 融合模型已保存为 cnn_addition_fusion_all_model.keras")
# Out:
#  3/15 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# d:\Venv\envs\TarRec\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer']
# Received: inputs=Tensor(shape=(32, 128, 128, 1))
#   warnings.warn(msg)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# d:\Venv\envs\TarRec\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer']
# Received: inputs=Tensor(shape=(None, 128, 128, 1))
#   warnings.warn(msg)
# d:\Venv\envs\TarRec\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer']
# Received: inputs=Tensor(shape=(32, 128, 128, 1, 1))
#   warnings.warn(msg)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# d:\Venv\envs\TarRec\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer']
# Received: inputs=Tensor(shape=(None, 128, 128, 1, 1))
#   warnings.warn(msg)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Epoch 1/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5009 - loss: 2.3670 - val_accuracy: 1.0000 - val_loss: 0.0611 - learning_rate: 0.0010
# Epoch 2/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9516 - loss: 0.1205 - val_accuracy: 1.0000 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 3/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.0508 - val_accuracy: 1.0000 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 4/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9935 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 5/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 6/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 7/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9907 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 8/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 9.2352e-04 - learning_rate: 0.0010
# Epoch 9/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 8.3798e-04 - learning_rate: 0.0010
# Epoch 10/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 7.5015e-04 - learning_rate: 0.0010
# Epoch 11/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 5.9185e-04 - learning_rate: 0.0010
# Epoch 12/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 4.5319e-04 - learning_rate: 0.0010
# Epoch 13/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 3.7758e-04 - learning_rate: 0.0010
# Epoch 14/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 3.3752e-04 - learning_rate: 0.0010
# Epoch 15/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 2.9950e-04 - learning_rate: 0.0010
# Epoch 16/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 2.4446e-04 - learning_rate: 0.0010
# Epoch 17/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 2.3297e-04 - learning_rate: 0.0010
# Epoch 18/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 2.1909e-04 - learning_rate: 0.0010
# Epoch 19/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 2.9730e-04 - learning_rate: 0.0010
# Epoch 20/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 2.2979e-04 - learning_rate: 0.0010
# Epoch 21/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 1.6066e-04 - learning_rate: 0.0010
# Epoch 22/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.2186e-04 - val_accuracy: 1.0000 - val_loss: 1.2868e-04 - learning_rate: 0.0010
# Epoch 23/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 9.4772e-05 - learning_rate: 0.0010
# Epoch 24/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.6260e-04 - val_accuracy: 1.0000 - val_loss: 8.1670e-05 - learning_rate: 0.0010
# Epoch 25/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 8.1075e-05 - learning_rate: 0.0010
# Epoch 26/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 9.3378e-04 - val_accuracy: 1.0000 - val_loss: 7.2947e-05 - learning_rate: 0.0010
# Epoch 27/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 7.4951e-05 - learning_rate: 0.0010
# Epoch 28/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.1282e-04 - val_accuracy: 1.0000 - val_loss: 7.6454e-05 - learning_rate: 5.0000e-04
# Epoch 29/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.9287e-04 - val_accuracy: 1.0000 - val_loss: 7.4934e-05 - learning_rate: 5.0000e-04
# Epoch 30/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 7.0010e-05 - learning_rate: 5.0000e-04
# 4/4 - 0s - 10ms/step - accuracy: 0.9658 - loss: 0.2336
#
# ✅ 融合模型测试集准确率: 0.9658
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📊 分类报告:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9231    0.9600        39
#            1     1.0000    0.9744    0.9870        39
#            2     0.9070    1.0000    0.9512        39
#
#     accuracy                         0.9658       117
#    macro avg     0.9690    0.9658    0.9661       117
# weighted avg     0.9690    0.9658    0.9661       117
# ✅ 融合模型已保存为 cnn_addition_fusion_all_model.keras
